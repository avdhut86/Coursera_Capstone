# %% [markdown]
# # Coursera Capstone

# %% [markdown]
# ### This notebook will be mainly used for the capstone project

# %%
import pandas as pd
import Numpy as np
print("Hello Capstone Project Course!")
# Out:
#   File "<ipython-input-2-4547a0f32b9e>", line 1
#     import pandas as pd
#                 ^
# SyntaxError: invalid syntax
